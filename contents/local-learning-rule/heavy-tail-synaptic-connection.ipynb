# %% [markdown]
# # シナプス結合強度の不均一性
# (概要)
# シナプス結合強度は正規分布に従わず，対数正規分布のような裾の重い分布 (heavy-tailed distribution) に従う．すなわち，多くの弱いシナプス結合と少数の強いシナプス結合が存在する．これは電気生理学的なEPSP (シナプス後電位) の測定や電子顕微鏡によるコネクトームの解析により明らかになっている．
#
# 本章では (Lynn, Holmes & Palmer, Nature Physics. 2024) で提案された，シナプス結合が裾の重い分布に従うネットワークを生成する発達モデルを紹介する．
#
# コードに関しては <https://github.com/ChrisWLynn/Heavy_tailed_connectivity> を参考に作成した．

# %%
using PyPlot, Random, Distributions, LinearAlgebra, StatsBase
using Graphs, GraphPlot, SimpleWeightedGraphs
using SpecialFunctions
using ProgressMeter
rc("axes.spines", top=false, right=false)
rc("font", family="Arial")

# %% [markdown]
# まず，活動に非依存的なモデルを紹介する．このモデルではネットワーク全体のシナプス結合強度の和 ($S$) が一定になるようにシナプスの枝刈りと2通りの増強を行う．
#
# 枝刈りの過程ではシナプスの結合強度に「よらず」，一様にシナプスが選択されて枝刈りされる．その際に減少した結合強度分を次のように他のシナプス結合に付与する．
# 確率 $p$ でシナプス結合強度に応じた確率でシナプスを選択し，増強する．確率 $1-p$ でランダムなシナプスを増強する．前者の過程により，強いシナプス結合はより増強される (The rich get richer)．

# %%
# based on scipy.fixed_point()
function fixed_point(func, x0; args=(), tol=1e-3, max_iter=100, method="del2")
    p0 = x0
    Δp = nothing
    for i in 1:max_iter
        p1 = func(p0, args...)
        if method == "del2"
            # Steffensen's Method with Aitken's Δ²
            p2 = func(p1, args...)
            p = p0 - (p1 - p0) .^2 ./ (p2 - 2 * p1 + p0)
        else
            p = p1
        end
        Δp = maximum(abs.(p .- p0))
        if Δp < tol
            return p
        end
        p0 = p
    end
    error("Failed to converge after $max_iter iterations. Δp=$Δp")
end;

# %%
f(x, A, β) = tanh.(β * A * x)

function generate_scale_free_network(;
        N=200, s_avg=1, p=0.5, num_iter=1000,
        num_prune_edge=50, symmetric=true, activity_depend=false, β=0.8)
    # set params
    if symmetric
        num_max_edge = round(Int, N * (N - 1) / 2)
        edge_indices = findall(triu(ones(Int64, N, N), 1) .== 1);
    else
        num_max_edge = N * (N - 1)
        edge_indices = findall((ones(Int64, N, N) - I(N)) .== 1);
    end
    S = s_avg * num_max_edge

    # initialization    
    indices_sample = sample(1:num_max_edge, S, replace=false)
    A = zeros(N, N)
    A[edge_indices[indices_sample]] .= 1

    @showprogress for t in 1:num_iter
        # pruning
        prune_indices = sample(1:num_max_edge, num_prune_edge, replace=false)
        ΔS = Int(sum(A[edge_indices[prune_indices]]))
        A[edge_indices[prune_indices]] .= 0
        
        # hebbian update
        ΔS_hebb = Int(sum(rand(Binomial(1, p), ΔS)))
        if activity_depend
            if symmetric
                A_norm = (A + A') / (s_avg*N)
            else
                A_norm = A / (s_avg*N)
            end
            x = fixed_point(f, -ones(N), args=(A_norm, β), method="iteration")
            D = diagm(1 .- x.^2)
            C = β * (I - β * D * A_norm) \ D
            hebb_indices = sample(1:num_max_edge, Weights(C[edge_indices]), ΔS_hebb, replace=false)
        else
            hebb_indices = sample(1:num_max_edge, Weights(A[edge_indices]), ΔS_hebb, replace=false)
        end
        # random update
        ΔS_rand = ΔS - ΔS_hebb
        rand_indices = sample(1:num_max_edge, ΔS_rand, replace=false)
        
        growth_indices = [hebb_indices; rand_indices]
        A[edge_indices[growth_indices]] .+= 1
    end

    A_flat = vcat(A[edge_indices]...)
    order_dict = sort(countmap(A_flat))
    order_arr = hcat(collect(keys(order_dict)), collect(values(order_dict)))
    order_arr[:, 2] ./= S

    if symmetric
        A = A + A'
    end
    return A, order_arr
end;
# Out:
# generate_scale_free_network (generic function with 1 method)

# %% [markdown]
# ニューロン数 ($N=20$) でグラフを描画しよう．少数の強い結合が存在していることが分かる．

# %%
A_small, _ = generate_scale_free_network(N=30, s_avg=1, p=0.5, num_iter=1000, num_prune_edge=10, symmetric=true, activity_depend=false);

# %%
g = SimpleWeightedGraph(A_small)
gplot(g, layout=circular_layout,
      edgelinewidth=weight.(edges(g)), 
      background_color="white",
      edgestrokec="black", plot_size=(5cm,5cm))
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Compose.UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Compose.UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([]), List([Compose.Form{Compose.RectanglePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}}(Compose.RectanglePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}[Compose.RectanglePrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}((-1.2cx, -1.2cy), 2.4cx, 2.4cy)], Symbol(""))]), List([Compose.Property{Compose.FillPrimitive}(Compose.FillPrimitive[Compose.FillPrimitive(RGBA{Float64}(1.0,1.0,1.0,1.0))])]), 0, false, false, false, false, nothing, nothing, 0.0, Symbol("")), Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([]), List([Compose.Property{Compose.LineWidthPrimitive}(Compose.LineWidthPrimitive[Compose.LineWidthPrimitive(0.09128709291752768mm), Compose.LineWidthPrimitive(0.04564354645876384mm), Compose.LineWidthPrimitive(0.09128709291752768mm), Compose.LineWidthPrimitive(0.04564354645876384mm), Compose.LineWidthPrimitive(0.04564354645876384mm), Compose.LineWidthPrimitive(0.09128709291752768mm), Compose.LineWidthPrimitive(0.27386127875258304mm), Compose.LineWidthPrimitive(0.18257418583505536mm), Compose.LineWidthPrimitive(0.04564354645876384mm), Compose.LineWidthPrimitive(0.04564354645876384mm)  …  Compose.LineWidthPrimitive(0.09128709291752768mm), Compose.LineWidthPrimitive(0.04564354645876384mm), Compose.LineWidthPrimitive(0.09128709291752768mm), Compose.LineWidthPrimitive(0.18257418583505536mm), Compose.LineWidthPrimitive(0.04564354645876384mm), Compose.LineWidthPrimitive(0.13693063937629152mm), Compose.LineWidthPrimitive(0.18257418583505536mm), Compose.LineWidthPrimitive(0.09128709291752768mm), Compose.LineWidthPrimitive(0.09128709291752768mm), Compose.LineWidthPrimitive(0.3651483716701107mm)]), Compose.Property{Compose.StrokePrimitive}(Compose.StrokePrimitive[Compose.StrokePrimitive(RGBA{Float64}(0.0,0.0,0.0,1.0))])]), 0, false, false, false, false, nothing, nothing, 0.0, Symbol("")), Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9641129123203059cx, 0.2524891824572516cy), (0.9275801460561005cx, 0.3655448062926431cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.9596676889047345cx, 0.250792117826627cy), (0.8274969062040185cx, 0.5492877464940917cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.7785682402246087cx, 0.625025977414621cy), (0.699579360509197cx, 0.7132352353030951cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.951415463759471 ...

# %% [markdown]
# ニューロン数を ($N=200$) に増やし，各結合強度の出現頻度を描画しよう．
#
# 各結合強度の出現頻度を予測する理論的式は以下で与えられる．
#
# $s$が大きいときは$\Gamma(s)$はInfとなりうる．そこで，`loggamma`関数を用いることとする．

# %%
P(s, s_avg, p) = exp(loggamma(s + s_avg * (1/p - 1)) - loggamma(s + s_avg * (1/p - 1) + 1/p + 1))
# Out:
# P (generic function with 1 method)

# %%
s_avg = 1
N = 500
order_activ_indep = []
P_activ_indep = []

ps = [0.25, 0.5, 0.75]
s_arr = exp10.(range(1e-8, stop=3, length=40));
for p in ps
    _, order_arr = generate_scale_free_network(
        N=N, s_avg=s_avg, p=p, num_iter=8000, 
        num_prune_edge=100, symmetric=true, activity_depend=false);
    P_arr = P.(s_arr, s_avg, p);
    P_arr ./= sum(P_arr);#$(40 / length(s_arr));
    push!(order_activ_indep, order_arr)
    push!(P_activ_indep, P_arr)
end
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:12m
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:11
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:09

# %%
cmap = plt.get_cmap("Accent")

fig, axes = subplots(1,3, figsize=(6, 3.1), sharex="all", sharey="all")
fig.suptitle("Activity independent model (w/ Symmetric connection)", y=0.92)
for i in 1:length(ps)
    axes[i].set_title(L"$p=" *"$(ps[i])"* L"$", math_fontfamily="cm")
    axes[i].plot(s_arr, P_activ_indep[i] / (P_activ_indep[i][1] / order_activ_indep[i][2, 2]), c="k", label="Analytic")
    axes[i].scatter(order_activ_indep[i][:, 1], order_activ_indep[i][:, 2], c=cmap(i-1)[1:3], alpha=0.8, label="Numeric", clip_on=false)
    axes[i].set_xscale("log"); axes[i].set_yscale("log")
    axes[i].set_ylim(5e-6, 1); axes[i].set_xlim(1, 1e3)
    axes[i].legend(labelspacing=0.2, prop=Dict("size" => 9))
end
axes[2].set_xlabel(L"Connection strengths $s$", math_fontfamily="cm")
axes[1].set_ylabel("Probability")
fig.tight_layout()
# Out:
# Figure(PyObject <Figure size 600x310 with 3 Axes>)

# %%
p = 0.5
s_avg = 1
βs = [0.01, 0.5, 1.0]
order_activ_dep = []
for β in βs
    _, order_arr = generate_scale_free_network(
        N=N, s_avg=s_avg, p=p, num_iter=8000, num_prune_edge=100, 
        symmetric=true, activity_depend=true, β=β)
    push!(order_activ_dep, order_arr)
end
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:01:33
# Progress: 100%|█████████████████████████████████████████| Time: 0:01:37
# Progress: 100%|█████████████████████████████████████████| Time: 0:02:06

# %%
cmap2 = plt.get_cmap("viridis")

figure(figsize=(3.2, 3.2))
title("Activity dependent model\n(w/ Symmetric connection)")
plot(s_arr, P_activ_indep[2] / (P_activ_indep[2][1] / order_activ_indep[2][2, 2]), c="k", label=L"$\beta=0$"*"\n(analytic)")
for i in 1:length(βs)
    scatter(order_activ_dep[i][:, 1], order_activ_dep[i][:, 2], c=cmap2(i/(length(βs)))[1:3], alpha=1, label=L"$\beta=" *"$(βs[i])"* L"$", clip_on=false)
end
xscale("log"); yscale("log")
ylim(5e-6, 1); xlim(1, 2e2)
legend(labelspacing=0.2, prop=Dict("size" => 9))
xlabel(L"Connection strengths $s$", math_fontfamily="cm")
ylabel("Probability")
tight_layout()
# Out:
# Figure(PyObject <Figure size 320x320 with 1 Axes>)
