# %% [markdown]
# # 確率過程と確率微分方程式
#
# 確率過程と確率微分方程式（SDE: Stochastic Differential Equation）は、ランダム性を含む動的なシステムを表現するための重要なツールです。以下にそれぞれについて説明します。
#
# ---
#
# ### 確率過程 (Stochastic Process)
# 確率過程は、時間や空間にわたるランダムな変数の集合を指します。簡単に言えば、時間の進行に伴ってランダムに変化する量を表します。
#
# - **定義**
#   確率過程 \( X(t) \) は、時間 \( t \) における確率変数 \( X_t \) の集合です。
#   形式的には、確率空間 \((\Omega, \mathcal{F}, P)\) 上で定義される \( X(t): \Omega \to \mathbb{R} \) の族です。
#
# - **種類**
#   1. **マルコフ過程**: 現在の状態が未来の状態にのみ影響を与える特性を持つ（記憶のない性質）。
#   2. **ウィーナー過程（ブラウン運動）**: 時間とともに増加する正規分布を持つ連続な確率過程。
#   3. **ポアソン過程**: 一定の速度でランダムに起こる事象のモデル化。
#
# - **応用**
#   確率過程は、物理学、経済学、金融工学、生多くの分野で用いられます。
#
# ---
#
# ### 確率微分方程式 (Stochastic Differential Equation, SDE)
# 確率微分方程式は、確率過程のダイナミクスを記述する微分方程式です。通常の微分方程式に確率的な要素が加わった形です。
#
# - **基本形**
#   確率微分方程式の一般形は以下のように書かれます：
#   \[
#   dX_t = a(X_t, t) dt + b(X_t, t) dW_t
#   \]
#   - \( X_t \): 状態変数（確率過程）
#   - \( a(X_t, t) \): ドリフト項（決定論的な変化）
#   - \( b(X_t, t) \): 拡散項（ランダムな変化）
#   - \( W_t \): ウィーナー過程（ブラウン運動）
#
# - **解法**
#   確率微分方程式を解くには、以下の方法が用いられます：
#   1. **伊藤の積分法 (Itô calculus)**:
#       確率微分方程式の標準的な解法。
#   2. **数値的手法**:
#       - **オイラー・マルヤマ法**: 簡易的な数値解法。
#       - **ミルシュタイン法**: 高次精度を持つ解法。
#
# - **応用**
#   - **金融工学**: ブラック-ショールズ方程式や金利モデル。
#   - **物理学**象のモデリング。
#   - **生物学**: 生物的過程の確率的な変動のモデル。
#
# ---
#
# ### 確率過程とSDEの関係
# 確率微分方程式は、確率過程の性質や振る舞いを動的に記述するためのモデルです。
#
# 何か特定のトピック（例：数値解法、特定のモデルなど）について知りたい場合、ぜひお知らせください！
