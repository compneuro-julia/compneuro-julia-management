# %%
using PyPlot, Random

# %%
mosaic = """
    AABB
    AACD
    """
# Out:
# "AABB\nAACD\n"

# %%
ax = figure(figsize=(6, 3), constrained_layout=true).subplot_mosaic(mosaic);
ax["A"].bar(["a", "b", "c"], [5, 7, 9])
ax["B"].plot([1, 2, 3])
ax["C"].hist(randn(500))
ax["D"].imshow([[1, 2], [2, 1]])
# Out:
# Figure(PyObject <Figure size 600x300 with 4 Axes>)
# ┌ Warning: `vendor()` is deprecated, use `BLAS.get_config()` and inspect the output instead
# │   caller = npyinitialize() at numpy.jl:67
# └ @ PyCall C:\Users\yamtak\.julia\packages\PyCall\3fwVL\src\numpy.jl:67
# PyObject <matplotlib.image.AxesImage object at 0x000000006307D430>
