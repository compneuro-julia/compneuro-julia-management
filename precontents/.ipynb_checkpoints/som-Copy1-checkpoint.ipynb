# %% [markdown]
# # Kohonen self organizing map

# %%
using Random, PyPlot, MAT, ProgressMeter

# %%
file = matopen("data.mat")
x = read(file, "T");

file = matopen("init.mat")
w = read(file, "mu");

# %%
# inputs 
Nin = 2400 # num of inputs
Din = 5  # dims of inputs 

# outputs
width_out = 64
w = reshape(w, (64,64,5));

# %%
function som_plot(x, w)
    figure(figsize=(6, 6))
    subplot(2,2,1)
    title("Retinotopic map")
    scatter(x[:, 1], x[:, 2], s=5)
    scatter(w[:, :, 1], w[:, :, 2], s=5) # w[i, j, 1]とw[i, j, 2]の点をプロット
    plot(w[:, :, 1], w[:, :, 2], "k", linewidth=1); 
    plot(w[:, :, 1]', w[:, :, 2]', "k", linewidth=1)
    
    ORmap = atan.(w[:, :, 5], w[:, :, 4]); # get angle of polar 
    subplot(2,2,2)
    title("Orientation (OR) angle map")
    imshow(ORmap, cmap="hsv", origin="lower")

    subplot(2,2,3)
    title("Ocular dominance (OD) map")
    imshow(w[:, :, 3], cmap="gray", origin="lower") 
    
    sizex, sizey = 64, 64
    x, y = 0:sizex-1, 0:sizey-1
    X, Y = ones(sizey) * x', y * ones(sizex)';
    
    subplot(2,2,4)
    title("Contours of OD and OR")
    contour(X, Y, ORmap, cmap="hsv")
    contour(X, Y, w[:, :, 3], colors="k", levels=1)
    tight_layout()
end;

# %%
som_plot(x, w)
# Out:
# Figure(PyObject <Figure size 600x600 with 4 Axes>)

# %%
# Gaussian mask for inputs
function GaussianMask(sizex=9, sizey=9; σ=5)
    x, y = 0:sizex-1, 0:sizey-1
    X, Y = ones(sizey) * x', y * ones(sizex)' 
    
    x0, y0 = (sizex-1) / 2, (sizey-1) / 2
    mask = exp.(-((X .- x0) .^2 + (Y .- y0) .^2) / (2.0(σ^2)))
    return mask ./ sum(mask)
end
# Out:
# GaussianMask (generic function with 3 methods)

# %%
function SOM!(x, w)
    η0 = 0.5; # update rate
    σ0 = 6; # width
    T = 100; # training steps
    @showprogress for t in 1:T
        η = η0 * (1 - t/T); # update rate
        σ = round(Int, σ0 * (1 - t/T)); # decay from large to small
        mask = GaussianMask(2σ+1, 2σ+1, σ=σ);
        
        # loop for the Nin inputs
        for i in 1:Nin
            dist = sum([(x[i, j] .- w[:, :, j]).^2 for j in 1:Din]) # distance between input and neurons
            win_idx = argmin(dist) # winner index
            idx = [max(1,win_idx[j] - σ):min(width_out, win_idx[j] + σ) for j in 1:2] # neighbor indices
            # update the winner & neighbor neuron    
            for j in 1:Din
                w[idx..., j] += η * mask[1:length(idx[1]), 1:length(idx[2])] .* (x[i, j] .- w[idx..., j]);
            end
        end
    end
end
# Out:
# SOM! (generic function with 1 method)

# %%
SOM!(x, w)
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:3239m9mmm

# %%
som_plot(x, w)
# Out:
# Figure(PyObject <Figure size 600x600 with 4 Axes>)

# %%
file = matopen("optimized.mat")
wo = read(file, "mu");

# %%
wo = reshape(wo, (64,64,5));

# %%
som_plot(x, wo)
# Out:
# Figure(PyObject <Figure size 600x600 with 4 Axes>)
