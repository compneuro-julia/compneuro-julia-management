# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io

# %%
mat = scipy.io.loadmat('model_parameters.mat')

# %%
mat
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: MACI64, Created on: Wed Oct 19 13:51:25 2016',
#  '__version__': '1.0',
#  '__globals__': [],
#  'A': array([[-2.00000000e-01, -5.74997138e-02, -1.36638393e-03, ...,
#           7.49994135e-03, -1.19109225e-02, -7.39351575e-03],
#         [ 5.51220146e-02,  1.58475003e-02,  3.76589174e-04, ...,
#           8.11606659e-03, -1.35624301e-02, -3.43548385e-02],
#         [ 2.14781651e-02,  6.17494172e-03,  1.46737098e-04, ...,
#           6.14311885e-03, -1.51778649e-02, -6.39926893e-02],
#         ...,
#         [-8.09037938e-53, -6.02903356e-48, -3.71362366e-44, ...,
#          -1.17607474e-03,  1.48172401e-02,  5.11321033e-02],
#         [-1.57834005e-57, -1.17619517e-52, -7.24485304e-49, ...,
#          -2.98837675e-03,  1.34714115e-02,  2.03561914e-02],
#         [ 4.17660449e-64,  3.11244843e-59,  1.91713349e-55, ...,
#          -3.15091724e-03,  1.20376007e-02, -8.88385574e-03]]),
#  'kGam': array([[2]], dtype=uint8),
# ...

# %%
A = mat["A"]

# %%
A.shape
# Out:
# (256, 248)

# %%
plt.imshow(A[:, 10].reshape(16, 16))

# %%
C = np.linalg.inv(A.T @ A)# + 1e-2*np.eye(248))

# %%
C.shape
# Out:
# (248, 248)

# %%
plt.imshow(C[200:, 200:], cmap="bwr")

# %%
C
# Out:
# array([[20241327.98809876,  7406679.27368532, -1135044.85331027, ...,
#         -1184739.4603278 ,  3407726.74848192, -1981076.97933995],
#        [ 7406679.21770464,  3117521.17044379,  -464338.93315164, ...,
#         -1077191.72465279,  1836939.21553615, -1199848.79937018],
#        [-1135045.03887464,  -464339.00559346,   647292.32239006, ...,
#            43278.75827315,  -707972.17355765,  -421182.39369282],
#        ...,
#        [-1184739.20659885, -1077191.64565509,    43278.70363803, ...,
#          5306207.53149012, -2792808.2772126 ,  1068056.05355603],
#        [ 3407726.69334492,  1836939.21542518,  -707972.10888568, ...,
#         -2792808.34940247,  4361717.5038372 ,  -560121.3971111 ],
#        [-1981076.7462893 , -1199848.70424452,  -421182.39734928, ...,
#          1068055.92631934,  -560121.28421587,  4226350.90869365]])

# %%
plt.imshow(A.T @ A)
